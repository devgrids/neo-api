# %%
from ai.text_to_image.dreamlike_art.anime_dreamlike_art_text_to_image import AnimeDreamlikeArtTextToImage
import matplotlib.pyplot as plt

text_to_image = AnimeDreamlikeArtTextToImage()
# Out:
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
from ai.text_to_image.dreamlike_art.diffusion_dreamlike_art_text_to_image import DiffusionDreamlikeArtTextToImage
import matplotlib.pyplot as plt

text_to_image = DiffusionDreamlikeArtTextToImage()
# Out:
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
prompt = """dreamlikeart, shark vs cocodrile
"""

# %%
params = {'num_inference_steps': 100, 'num_images_per_prompt': 2}
# params = {'num_inference_steps': 100, 'width': 512, 'height': int(1.5*640)}
# params = {'num_inference_steps': 100, 'num_images_per_prompt': 2}
# params = {'num_inference_steps': 100, 'num_images_per_prompt': 2, 'negative_prompt': 'ugly, distorted, low quality'}

# %%
images = text_to_image.generate(prompt, params)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
print("[PROMPT]: ",prompt)
num_images = len(images)
if num_images>1:
  fig, ax = plt.subplots(nrows=1, ncols=num_images)
  for i in range(num_images):
    ax[i].imshow(images[i]);
    ax[i].axis('off');
else:
    fig = plt.figure()
    plt.imshow(images[0]);
    plt.axis('off');
plt.tight_layout()
# Out:
# [PROMPT]:  dreamlikeart, shark vs cocodrile
